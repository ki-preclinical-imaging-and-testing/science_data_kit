# %%
import pandas as pd
from pathlib import Path
from datetime import datetime

input_fname = '../LauraM_USGI_uCT_Sessions.csv'
df = pd.read_csv(input_fname)

# %%
df
# Out:
#                                    Filepath Study     Cage Individual  \
# 0           U37/10_21_2022/Cage 6/1L/1L_Rec   U37  Cage006         1L
# 1           U37/10_21_2022/Cage 6/1R/1R_Rec   U37  Cage006         1R
# 2           U37/10_21_2022/Cage 8/NP/NP_Rec   U37  Cage008         NP
# 3           U37/10_21_2022/Cage 8/1L/1L_Rec   U37  Cage008         1L
# 4           U37/10_21_2022/Cage 8/1R/1R_Rec   U37  Cage008         1R
# ...                                     ...   ...      ...        ...
# 2760   02.3.22_740_SW/cage 90/2660/2660_Rec   TBD  Cage090       2660
# 2761   02.3.22_740_SW/cage 90/2674/2674_Rec   TBD  Cage090       2674
# 2762  02.3.22_740_SW/cage 112/2933/2933_Rec   TBD  Cage112       2933
# 2763  02.3.22_740_SW/cage 112/2932/2932_Rec   TBD  Cage112       2932
# 2764        U37/10_21_2022/Cage 6/NP/NP_Rec   U37  Cage006         NP
#
#             Date
# 0     2022/10/21
# 1     2022/10/21
# 2     2022/10/21
# 3     2022/10/21
# 4     2022/10/21
# ...

# %%
df.rename(columns={
    'Filepath': 'filepath',
    'Individual': 'Mouse'
}, inplace=True)

# %%
df.to_csv('Mouse_Taxa.csv', index=False)
